# %% [markdown]
# Write a function to calculate the enterprise value (EV) for a firm, using discounted cash flow method:
#
#
#
#
# > Add blockquote
#
#
# ![image.png](attachment:image.png)
# <style>img{width:500px;}</style>

# %% [markdown]
# * Assume a 5-year DCF modeling
#
# * The subject firm has a free cash flow to firm of **fcff** according to the latest annual report.
#
# * assume a weighted average cost of capital of **wacc**
#
# * Assume an annual growth of the free cash flow to firm of **G**
#
# * Assume a terminal growth rate of **g** with a default value of 2\%

# %% [markdown]
# function **pv_t** returns the present value of free cash flow for the **t**th year

# %%
def pv_t(fcff,wacc,t):
    return fcff / (1+wacc)**t

# %% [markdown]
# function **pv_perpetuity** calculates the **TV** (terminal value) in the above mentioned formula.
#
# * Complete the missing **...** parts

# %%
def pv_perpetuity(fcff_n,wacc,g=.02):
    return  ##edit here##    ... / (wacc - ...)

# %% [markdown]
# Finally, the DCF comulates the present values of expected cash flows

# %%
#### UNCOMMENT HERE AND EDIT

# def DCF(fcff,wacc,G,g=.02,n=5):
#     FCF_sum=0
#     for t in range(1,...):
#         FCF_sum+= pv_t(...)

#     TV = pv_perpetuity(...)

#     FCF_sum += pv_t(...)

#     return FCF_sum

# %% [markdown]
# Print the output for :

# %%
#### UNCOMMENT
#DCF(3231,.08,.04)
