# %% [markdown]
# # Introduction of Auto-EDA tools
#
# 1. 📊 Dataprep 📚
# 2. 📊 AutoViz 📚
# 3. 📊 SweetViz 📚
# 4. 📊 D-Tale 📚
#
#
# #### datasets:
# * Titanic passengers
#
#
# Based on https://www.kaggle.com/code/andreshg/automatic-eda-libraries-comparisson
#
# In this notebook we are going to compare the top Auto EDA libraries that really facilite the dataset analysis and visualziation!
#
# The main idea is that you can compare time to plot and results of each AutoEda library so you can select the best for your work.

# %%
# !pip install pandas setuptools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install numpy==1.24.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for numpy==1.24.4 from https://files.pythonhosted.org/packages/d8/ec/ebef2f7d7c28503f958f0f8b992e7ce606fb74f9e891199329d5f5f87404/numpy-1.24.4-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.4/14.8 MB 11.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/14.8 MB 10.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/14.8 MB 12.0 MB/s eta 0:00:02
#    ------ --------------------------------- 2.5/14.8 MB 14.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.9/14.8 MB 17.6 MB/s eta 0:00:01
#    -------------- ------------------------- 5.3/14.8 MB 20.1 MB/s eta 0:00:01
#    ------------------ --------------------- 6.8/14.8 MB 21.9 MB/s eta 0:00:01
# ...

# %%
import datetime as dt
import pandas as pd
import numpy as np
import os
import setuptools

# %% [markdown]
# #### Preparing the DataFrame

# %%
import os
# documentation: https://docs.python.org/3/library/os.html

# Set target directory path to SESSION 1 folder
new_path = r"C:\Users\sharafi\Dropbox\ML course\Data Analytics Course\Data Science Course WS2025"  # use raw string or double backslashes on Windows

# Change the current working directory
os.chdir(new_path)

# Optional: Verify current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\sharafi\Dropbox\ML course\Data Analytics Course\Data Science Course WS2025

# %%
df = pd.concat([
        pd.read_csv('Input/Titanic/test.csv'),
        pd.read_csv('Input/Titanic/train.csv')
    ], axis=0)\
    .drop('Survived', axis=1)\
    .merge(
        pd.read_csv('Input/Titanic/gender_submission.csv'),
        on='PassengerId'
    )

df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
import re
df['Title']=df.Name.apply(lambda x: re.findall(', \w+.',x)[0][1:])

# %% [markdown]
# <a id='2'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">2. 📊 AutoViz 📚</p>
#
# AutoViz stands out of the crowd of freeware Pythonic Rapid EDA Automation tools, doing things in a very fast way, the way better than its close freeware rivals like SweetViz or Pandas Profiling

# %%
# !pip install autoviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for autoviz from https://files.pythonhosted.org/packages/51/92/eea3f91d7c5788a37eb739399cf99c3b2d3b6c1f25c1b9e51a2e85f2a00a/autoviz-0.1.905-py3-none-any.whl.metadata
#   Using cached autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/00/09/abb305dce85911b8fba382926cfc57f2f257729e25937fdcc63f3a1a67f9/wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# ...
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/91/db/a0335710caaa6d0aebdaa65ad4df789c15d89b7babd9a30277838a7d9aac/emoji-2.14.1-py3-none-any.whl.metadata
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# ...

# %%
# Start of AutoViz process
start_time = dt.datetime.now()
print("Started at ", start_time)
# Out:
# Started at  2025-08-25 13:52:59.503845

# %%
# !pip install jinja2==3.1.2
# !pip install markupsafe==2.1.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
print("Pandas version:", pd.__version__)
import jinja2
print("Jinja2 version:", jinja2.__version__)    
import autoviz
print("AutoViz version:", autoviz.__version__)
# Out:
# Pandas version: 1.5.3
# Jinja2 version: 3.1.2
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\__init__.py:22
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\__init__.py:48
#      24     import sys
#      25     msg = """
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
dftc = AV.AutoViz(
    filename='',
    sep='' ,
    depVar='Survived',
    dfte=df,
    header=0,
    verbose=1,
    lowess=False,
    chart_format='png',
    max_rows_analyzed=300000,
    max_cols_analyzed=30
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\__init__.py:22
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from autoviz.AutoViz_Class import AutoViz_Class
#       3 AV = AutoViz_Class()
#       4 dftc = AV.AutoViz(
#       5     filename='',
# ...

# %%
print('AutoViz finished!!')
finish_time = dt.datetime.now()
print("Finished at ", finish_time)
elapsed = finish_time - start_time
print("Elapsed time: ", elapsed)
# Out:
# AutoViz finished!!
# Finished at  2025-08-11 17:36:58.336362
# Elapsed time:  0:00:19.589024

# %% [markdown]
# <a id='3'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">3. 📊 SweetViz 📚</p>

# %%
pip install sweetviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\baner\anaconda3\envs\Global_use\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\baner\anaconda3\envs\Global_use\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\baner\anaconda3\envs\Global_use\Lib\site-packages)

# %%
import sweetviz as sv

# %%
# Start of Pandas Profiling process
start_time = dt.datetime.now()
print("Started at ", start_time)
# Out:
# Started at  2025-08-11 17:36:59.466663

# %%
advert_report = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 advert_report = sv.analyze(df)
#
# File c:\Users\baner\anaconda3\envs\Global_use\Lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ...

# %%
advert_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
advert_report = sv.compare(df[df['Survived']==0],df[df['Survived']==1])
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
advert_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
print('SweetViz finished!!')
finish_time = dt.datetime.now()
print("Finished at ", finish_time)
elapsed = finish_time - start_time
print("Elapsed time: ", elapsed)
# Out:
# SweetViz finished!!
# Finished at  2025-08-05 21:50:51.181982
# Elapsed time:  0:00:22.651298

# %%
#!pip install lux-api

# %%
import lux
import pandas as pd

# %%
df.head()
# Out:
#      PassengerId  Pclass  \
# 0        892         3
# 1        893         3
# 2        894         2
# 3        895         3
# 4        896         3
# 5        897         3
# 6        898         3
# 7        899         2
# 8        900         3
# 9        901         3
# 10       902         3
# 11       903         1
# 12       904         1
# 13       905         2
# 14       906         1
# 15       907         2
# 16       908         2
# 17       909         3
# 18       910         3
# 19       911         3
# 20       912         1
# 21       913         3
# 22       914         1
# 23       915         1
# 24       916         1
# 25       917         3
# 26       918         1
# 27       919         3
# 28       920         1
# 29       921         3
# 30       922         2
# 31       923         2
# 32       924         3
# 33       925         3
# 34       926         1
# 35       927         3
# 36       928         3
# 37       929         3
# ...

# %% [markdown]
# # References
#
# The references to the blog posts below may be helpful in your deeper delve into the universe of AutoViz
#
# * Pandas Profiling GitHub - https://github.com/pandas-profiling/pandas-profiling
# * Dan Roth, AutoViz: A New Tool for Automated Visualization - https://towardsdatascience.com/autoviz-a-new-tool-for-automated-visualization-ec9c1744a6ad
# * George Vyshnya, PROs and CONs of Rapid EDA Tools - https://medium.com/sbc-group-blog/pros-and-cons-of-rapid-eda-tools-e1ccd159ab07
# * SweetViz - https://towardsdatascience.com/sweetviz-automated-eda-in-python-a97e4cabacde
# * DataPrep - https://sfu-db.github.io/dataprep/user_guide/eda/plot.html
